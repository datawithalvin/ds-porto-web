# %%
import leafmap
import geopandas as gpd

# %%
# retrieve all collections from the maxarr open data catalog
leafmap.maxar_collections()
# Out:
# ['Gambia-flooding-8-11-2022',
#  'Hurricane-Fiona-9-19-2022',
#  'Hurricane-Ian-9-26-2022',
#  'Indonesia-Earthquake22',
#  'Kahramanmaras-turkey-earthquake-23',
#  'New-Zealand-Flooding22',
#  'New-Zealand-Flooding23',
#  'Sudan-flooding-8-22-2022',
#  'afghanistan-earthquake22',
#  'cyclone-emnati22',
#  'kentucky-flooding-7-29-2022',
#  'pakistan-flooding22',
#  'southafrica-flooding22',
#  'tonga-volcano21',
#  'volcano-indonesia21',
#  'yellowstone-flooding22']

# %%
collection = "volcano-indonesia21"
url = leafmap.maxar_collection_url(collection, dtype="geojson")
url
# Out:
# 'https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/volcano-indonesia21.geojson'

# %%
maxar_df = gpd.read_file(url)
display(f'total number of images: {len(maxar_df)}')
maxar_df.head(2)
# Out:
# 'total number of images: 284'
#                    datetime platform   gsd ard_metadata_version  \
# 0 2021-12-11 02:49:32+00:00     WV02  0.47                0.0.1
# 1 2021-12-11 02:49:32+00:00     WV02  0.47                0.0.1
#
#          catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 0  10300100CA966300        49  300020321103             7.2          63.1
# 1  10300100CA966300        49  300020321112             7.0          62.6
#
#    view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 0                  81.9             127.0                63.5      32749
# 1                  82.1             127.0                63.5      32749
#
#                                            proj:bbox  tile:data_area  \
# 0  727949.5239257812,9109843.75,730156.25,9111920...             4.5
# 1   729843.75,9109843.75,735156.25,9111923.217773438            11.0
#
#    tile:clouds_area  tile:clouds_percent  \
# 0               3.4                   75
# 1               6.9                   62
#
#                                               visual  \
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                             geometry
# 0  POLYGON ((113.07987 -8.02895, 113.06844 -8.029...
# 1  POLYGON ((113.11684 -8.02874, 113.08541 -8.028...

# %%
# visualize the footprints of the images on the map
m = leafmap.Map()
m.add_gdf(maxar_df, layer_name="Footprints")

m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %% [markdown]
# The earthquake started on November 21, 2022. Set end_date to 2022-11-21 to get all images captured before the earthquake.

# %%
pre_gdf = leafmap.maxar_search(collection, end_date='2021-12-04')
print(f'Total number of pre-event images: {len(pre_gdf)}')
pre_gdf.head(2)
# Out:
# Total number of pre-event images: 159
#                     datetime platform   gsd ard_metadata_version  \
# 28 2021-07-12 02:50:51+00:00     WV02  0.59                0.0.1
# 29 2021-07-12 02:50:51+00:00     WV02  0.58                0.0.1
#
#           catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 28  10300100C2996600        49  300020321011            28.4         185.3
# 29  10300100C2996600        49  300020321013            28.2         185.3
#
#     view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 28                  57.8              39.5                51.0      32749
# 29                  58.0              39.5                51.0      32749
#
#                                             proj:bbox  tile:data_area  \
# 28  719067.0776367188,9114843.75,720156.25,9116627...             1.8
# 29  719074.4018554688,9109843.75,720156.25,9115156.25             5.5
#
#     tile:clouds_area  tile:clouds_percent  \
# 28               0.0                    0
# 29               0.0                    0
#
#                                                visual  \
# 28  https://maxar-opendata.s3.amazonaws.com/events...
# 29  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                              geometry
# 28  POLYGON ((112.99734 -7.98681, 112.99642 -7.987...
# 29  POLYGON ((112.98760 -8.00015, 112.98776 -8.004...

# %%
post_gdf = leafmap.maxar_search(collection, start_date='2021-12-04')
print(f'Total number of post-event images: {len(post_gdf)}')
post_gdf.head(2)
# Out:
# Total number of post-event images: 125
#                    datetime platform   gsd ard_metadata_version  \
# 0 2021-12-11 02:49:32+00:00     WV02  0.47                0.0.1
# 1 2021-12-11 02:49:32+00:00     WV02  0.47                0.0.1
#
#          catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 0  10300100CA966300        49  300020321103             7.2          63.1
# 1  10300100CA966300        49  300020321112             7.0          62.6
#
#    view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 0                  81.9             127.0                63.5      32749
# 1                  82.1             127.0                63.5      32749
#
#                                            proj:bbox  tile:data_area  \
# 0  727949.5239257812,9109843.75,730156.25,9111920...             4.5
# 1   729843.75,9109843.75,735156.25,9111923.217773438            11.0
#
#    tile:clouds_area  tile:clouds_percent  \
# 0               3.4                   75
# 1               6.9                   62
#
#                                               visual  \
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                             geometry
# 0  POLYGON ((113.07987 -8.02895, 113.06844 -8.029...
# 1  POLYGON ((113.11684 -8.02874, 113.08541 -8.028...

# %%
m = leafmap.Map()
pre_style = {'color': 'red', 'fillColor': 'red', 'opacity': 1, 'fillOpacity': 0.5}
m.add_gdf(pre_gdf, layer_name='Pre-event', style=pre_style, info_mode='on_click')
m.add_gdf(post_gdf, layer_name='Post-event', info_mode='on_click')
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
bbox = m.user_roi_bounds()
bbox
# Out:
# [112.799, -8.1952, 113.0531, -8.0199]

# %%
pre_event = leafmap.maxar_search(collection, bbox=bbox, end_date='2021-12-04')
pre_event.tail(2)
# Out:
#                      datetime platform  gsd ard_metadata_version  \
# 261 2019-05-18 02:46:54+00:00     GE01  0.5                0.0.1
# 262 2019-05-18 02:46:55+00:00     GE01  0.5                0.0.1
#
#            catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 261  10500100164C2D00        49  300020321210            26.9         153.9
# 262  10500100164C2D00        49  300020321212            27.0         154.2
#
#      view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 261                  59.9              40.9                53.3      32749
# 262                  59.9              40.8                53.3      32749
#
#                                             proj:bbox  tile:data_area  \
# 261  709843.75,9094843.75,714403.076171875,9100156.25            23.5
# 262       709843.75,9089843.75,714179.6875,9095156.25            22.7
#
#      tile:clouds_area  tile:clouds_percent  \
# 261               0.0                    0
# 262               0.0                    0
#
#                                                 visual  \
# 261  https://maxar-opendata.s3.amazonaws.com/events...
# 262  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                               geometry
# 261  POLYGON ((112.90452 -8.13615, 112.90475 -8.184...
# 262  POLYGON ((112.90473 -8.18136, 112.90496 -8.229...

# %%
post_event = leafmap.maxar_search(collection, bbox=bbox, start_date='2021-12-04')
post_event.head(2)
# Out:
#                     datetime platform   gsd ard_metadata_version  \
# 73 2021-12-08 02:59:16+00:00     WV02  0.56                0.0.1
# 74 2021-12-08 02:59:16+00:00     WV02  0.56                0.0.1
#
#           catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 73  10300100CA7F9E00        49  300020320113            25.9         343.7
# 74  10300100CA7F9E00        49  300020320131            26.0         343.8
#
#     view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg  \
# 73                  60.6             129.3                65.6      32749
# 74                  60.5             129.3                65.6      32749
#
#                                             proj:bbox  tile:data_area  \
# 73  698587.9516601562,9109843.75,700156.25,9112751...             4.4
# 74  698547.0581054688,9104843.75,700156.25,9110156.25             8.4
#
#     tile:clouds_area  tile:clouds_percent  \
# 73               0.0                    0
# 74               0.0                    0
#
#                                                visual  \
# 73  https://maxar-opendata.s3.amazonaws.com/events...
# 74  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                              geometry
# 73  POLYGON ((112.80690 -8.02272, 112.80363 -8.022...
# 74  POLYGON ((112.80202 -8.04621, 112.80184 -8.094...

# %%
pre_tile = pre_event['catalog_id'].values[-1]
post_tile = post_event['catalog_id'].values[2]

display(pre_tile, post_tile)
# Out:
# '10500100164C2D00'
# '10300100CA7F9E00'

# %%
pre_stac = leafmap.maxar_tile_url(collection, pre_tile, dtype='json')
pre_stac
# Out:
# 'https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/volcano-indonesia21/10500100164C2D00.json'

# %%
post_stac = leafmap.maxar_tile_url(collection, post_tile, dtype='json')
post_stac
# Out:
# 'https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/volcano-indonesia21/10300100CA7F9E00.json'

# %%
import leafmap.foliumap as leafmap
m = leafmap.Map()
m.split_map(
    left_layer=post_stac,
    right_layer=pre_stac,
    left_label='Post-event',
    right_label='Pre-event',
)
m.set_center(-8.10755, 112.92605, 10)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_453928416ede44271930df6436b374e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_453928416ede44271930df6436b374e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_453928416ede44271930df6436b374e8 = L.map(
#                 &quot;map_453928416ede44271930df6436b374e8&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_453928416ede44271930df6436b374e8);
#
#
#
#
#
#             var tile_layer_05113ae6d80f7eb328609a009e03c357 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_453928416ede44271930df6436b374e8);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_453928416ede44271930df6436b374e8);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_453928416ede44271930df6436b374e8
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_84b8c04a5ab43a95794a7c9b7b612c82 = new L.Control.Draw(
#                 options
#             ).addTo( map_453928416ede44271930df6436b374e8 );
#             map_453928416ede44271930df6436b374e8.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_453928416ede44271930df6436b374e8.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_a5236fa2817342e4734b17042cd2b5e3 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_453928416ede44271930df6436b374e8.addControl(measure_control_a5236fa2817342e4734b17042cd2b5e3);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_453928416ede44271930df6436b374e8.setView(e.geocode.center, 11);
#             }).addTo(map_453928416ede44271930df6436b374e8);
#
#
#
#             map_453928416ede44271930df6436b374e8.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_06677ea9ff2e91796bd3408a28a58645 = L.tileLayer(
#                 &quot;https://titiler.xyz/mosaicjson/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?max_zoom=100\u0026max_native_zoom=100\u0026layer_name=Left+Layer\u0026url=https%3A%2F%2Fraw.githubusercontent.com%2Fgiswqs%2Fmaxar-open-data%2Fmaster%2Fdatasets%2Fvolcano-indonesia21%2F10300100CA7F9E00.json&quot;,
#                 {&quot;attributi
